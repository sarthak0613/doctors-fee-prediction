# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Creating empty data drame
df= pd.DataFrame({'Name':[''], 'Speciality':[''], 'Degree':[''], 'Year_of_experience':[''] , 'Location':[''] , 'City':[''] ,'dp_score':[''], 'npv':[''], 'consultation_fee':['']})
#Creating list of cities from where data is to be extracted
lis=['Bangalore','Delhi','Mumbai']
#speciality of doctors whose data to be extracted
Speciality = 'Rheumatologist'
#for loop to take city name form lis and each time change url according to city
for i in lis:
    driver = webdriver.Chrome()
    url = f'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22rheumatologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city={i}'
    driver.get(url)
    time.sleep(2)
    
    scroll_pause_time = 2 # You can set your own pause time. dont slow too slow that might not able to load more data
    screen_height = driver.execute_script("return window.screen.height;")  # get the screen height of the web
    A = 1

    while True:
        # scroll one screen height each time
        driver.execute_script("window.scrollTo(0, {screen_height}*{A});".format(screen_height=screen_height, A=A))
        A += 1
        time.sleep(scroll_pause_time)
        # update scroll height each time after scrolled, as the scroll height can change after we scrolled the page
        scroll_height = driver.execute_script("return document.body.scrollHeight;")
        # Break the loop when the height we need to scroll to is larger than the total scroll height
        if (screen_height) * A > scroll_height:
            break
    #after scrolling getting the HTML of webpage and extrancting data
    soup = BeautifulSoup(driver.page_source,'lxml')
    postings = soup.find_all('div' , class_= 'u-border-general--bottom')
    for post in postings:
        try:
            link = post.find('div' , class_ = 'listing-doctor-card').find('a').get('href')
            link_full = 'https://www.practo.com'+link
            driver.get(link_full)
            soup2 = BeautifulSoup(driver.page_source,'lxml')

            #extracting name
            try:
                name = soup2.find('h1' , class_ = 'c-profile__title u-bold u-d-inlineblock').text
            except:
                pass       
            #extracting degree
            try:
                Degree = soup2.find('p' , class_ = 'c-profile__details').text
            except:
                pass
            #extracting years of experience
            try:
                Year_of_experience = soup2.find('div' , class_ = 'c-profile__details').find_all('h2')[-1].text
            except:
                pass
            #extracting location
            try:
                Location = soup2.find('h4' , class_ = 'c-profile--clinic__location').text
            except:
                pass
            #extracting dp score
            try:
                dp_score = soup2.find('span' , class_ = 'u-green-text u-bold u-large-font').text.strip()
            except:
                pass
            #extracting npv
            try:
                npv = soup2.find('span' , class_ = 'u-smallest-font u-grey_3-text').text
            except:
                pass
            #extracting consulting fee
            try:
                consultant_fee = soup2.find('span' , class_ = 'u-strike').text.strip()
            except:
                consultant_fee = soup2.find('div' , class_ = 'u-f-right u-large-font u-bold u-valign--middle u-lheight-normal').text.strip()
            #appending all data into dataframe
            df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
        except:
            pass
# Out:
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)
# C:\Users\dellpc\AppData\Local\Temp\ipykernel_14836\4042374553.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name':name, 'Speciality':Speciality, 'Degree':Degree, 'Year_of_experience':Year_of_experience , 'Location':Location , 'City':i ,'dp_score':dp_score, 'npv':npv, 'consultation_fee':consultant_fee} , ignore_index = True)

# %%
df
# Out:
#                            Name      Speciality  \
# 0
# 1    Dr. Chethana Dharmapalaiah  Rheumatologist
# 2               Dr. Uma Karjigi  Rheumatologist
# 3               Dr. Srinivasa.C  Rheumatologist
# 4            Dr. Abhishek Patil  Rheumatologist
# 5            Dr. Prashant Bafna  Rheumatologist
# 6             Dr. Raghavendra H  Rheumatologist
# 7            Dr. Satish Kalanje  Rheumatologist
# 8             Dr. Pradeep Kumar  Rheumatologist
# 18                MBBS, MRCP (UK), CCT - Rheumatology
# 19  MBBS, MD - Medicine, MRCP (UK), DM - Clinical ...
# 20      MBBS, MD - Medicine, DM - Clinical Immunology
# 21  MBBS, MD - General Medicine, DNB - General Med...
# 22  MBBS, MD - General Medicine, Fellowship in Rhe...
# 23    DNB - Rheumatology, MBBS, MD - General Medicine
# 24  MBBS, DNB - General Medicine,  FRCP, Fellowshi...
# 25   MBBS, MD - General Medicine, PGCC - Rheumatology
# 26     MBBS, MD - General Medicine, DM - Rheumatology
# 27                            MBBS, MD - Rheumatology
# 28                     MBBS, DM - Clinical Immunology
# 29  MBBS, DNB - General Medicine, FRCP - Rheumatology
# 30  MD - General Medicine, MBBS, DM - Clinical Imm...
# 31  DM - Clinical Immunology, MD - General Medicin...
# 32     MBBS, DM - Rheumatology, MD - General Medicine
# 33             DM - Rheumatology, MD - Medicine, MBBS
# 34            MBBS, MD - Medicine, DNB - Rheumatology
# 35  MBBS, MD - General Medicine, Fellowship in Rhe...
# 36                            MBBS, MS - Orthopaedics
# 37    MBBS, MD - General Medicine, CCT - Rheumatology
# 38                            MBBS, MD - Rheumatology
# 39                           MBBS, CCT - Rheumatology
# 40            MBBS, DNB - General Medicine, MRCP (UK)
# 41  MBBS, MD - General Medicine, Fellowship in Rhe...
# 42     MBBS, MD - General Medicine, DM - Rheumatology
# 43  MBBS, Diploma in Orthopaedics, MRCS (UK), DNB ...
# 44                            MBBS, MD - Rheumatology
# 45  Fellowship in Rheumatology, Graduate Certifica...
# 46  MD - Physician, DNB - Rheumatology, Diploma in...
# 47    MD - General Medicine, MBBS, DNB - Rheumatology
#
#                                    Year_of_experience  \
# 0
# 1   18 Years Experience Overall  (16 years as spec...
# 2   22 Years Experience Overall  (7 years as speci...
# 3   20 Years Experience Overall  (9 years as speci...
# 4   12 Years Experience Overall  (5 years as speci...
# 5   9 Years Experience Overall  (2 years as specia...
# 6   11 Years Experience Overall  (2 years as speci...
# 7   31 Years Experience Overall  (24 years as spec...
# 8   24 Years Experience Overall  (11 years as spec...
# 9                         12 Years Experience Overall
# 10  14 Years Experience Overall  (1 year as specia...
# 11  21 Years Experience Overall  (16 years as spec...
# 12  15 Years Experience Overall  (8 years as speci...
# 13  21 Years Experience Overall  (13 years as spec...
# 14  36 Years Experience Overall  (27 years as spec...
# 15  39 Years Experience Overall  (28 years as spec...
# 16  14 Years Experience Overall  (9 years as speci...
# 17                        23 Years Experience Overall
# 18  21 Years Experience Overall  (10 years as spec...
# 19  12 Years Experience Overall  (6 years as speci...
# 20  31 Years Experience Overall  (24 years as spec...
# 21  35 Years Experience Overall  (17 years as spec...
# 22  23 Years Experience Overall  (18 years as spec...
# 23  19 Years Experience Overall  (6 years as speci...
# 24  33 Years Experience Overall  (26 years as spec...
# 25  41 Years Experience Overall  (24 years as spec...
# 26  10 Years Experience Overall  (1 year as specia...
# 27  37 Years Experience Overall  (29 years as spec...
# 31                Janakpuri, Delhi      Delhi     100%    (17 votes)
# 32            Paschim Vihar, Delhi      Delhi     100%    (17 votes)
# 33         Dwarka Sector 12, Delhi      Delhi      92%    (12 votes)
# 34           Rajouri Garden, Delhi      Delhi      73%    (15 votes)
# 35           Dilshad Garden, Delhi      Delhi      73%    (15 votes)
# 36           Shanti Niketan, Delhi      Delhi      73%    (15 votes)
# 37                   Parel, Mumbai     Mumbai      73%    (15 votes)
# 38                   Mahim, Mumbai     Mumbai      73%    (15 votes)
# 39          Mumbai Central, Mumbai     Mumbai     100%    (15 votes)
# 40             Charni Road, Mumbai     Mumbai     100%    (23 votes)
# 41            Bhandup West, Mumbai     Mumbai      94%  (2885 votes)
# 42                 Mazgaon, Mumbai     Mumbai      90%    (21 votes)
# 43          Kandivali East, Mumbai     Mumbai      89%    (28 votes)
# 44          Vileparle West, Mumbai     Mumbai      92%    (25 votes)
# 45            Andheri East, Mumbai     Mumbai      92%    (25 votes)
# 46                 Mazgaon, Mumbai     Mumbai      92%    (25 votes)
# 47           Borivali West, Mumbai     Mumbai      92%    (25 votes)
#
#    consultation_fee
# 0
# 1        ₹ 1000 fee
# 2        ₹ 1000 fee
# 3         ₹ 850 fee
# 4         ₹ 900 fee
# 5         ₹ 900 fee
# 6         ₹ 850 fee
# 7        ₹ 1000 fee
# 8         ₹ 900 fee
# 9         ₹ 850 fee
# 10        ₹ 810 fee
# 11       ₹ 1000 fee
# 12        ₹ 900 fee
# 13       ₹ 1200 fee
# 14       ₹ 1000 fee
# 15        ₹ 800 fee
# 16        ₹ 950 fee
# 17       ₹ 1000 fee
# 18       ₹ 1050 fee
# 19       ₹ 1400 fee
# 20       ₹ 2500 fee
# 21       ₹ 3000 fee
# 22       ₹ 1500 fee
# 23       ₹ 1400 fee
# 24       ₹ 1500 fee
# 25       ₹ 1000 fee
# 26       ₹ 1000 fee
# 27        ₹ 900 fee
# 28       ₹ 2000 fee
# 29        ₹ 600 fee
# 30       ₹ 1500 fee
# 31        ₹ 800 fee
# 32        ₹ 800 fee
# 33        ₹ 700 fee
# 34       ₹ 1000 fee
# 35        ₹ 700 fee
# 36        ₹ 600 fee
# 37       ₹ 2100 fee
# 38       ₹ 1800 fee
# 39       ₹ 1250 fee
# 40       ₹ 1500 fee
# 41        ₹ 800 fee
# 42       ₹ 2000 fee
# 43        ₹ 500 fee
# 44       ₹ 3000 fee
# 45       ₹ 1500 fee
# 46        ₹ 400 fee
# 47       ₹ 1200 fee

# %%
df.nunique()
# Out:
# Name                  48
# Speciality             2
# Degree                37
# Year_of_experience    45
# Location              39
# City                   4
# dp_score              18
# npv                   30
# consultation_fee      21
# dtype: int64

# %%
df['Speciality'].value_counts()
# Out:
# Rheumatologist    47
#                    1
# Name: Speciality, dtype: int64

# %%
df.to_csv('Rheumatologist.csv',index=False)

# %%
df2 = pd.concat(
    map(pd.read_csv, ['Cardiologist.csv','Dentist.csv','Gynecologist.csv','Orthopedist.csv','Rheumatologist.csv']),ignore_index=True)

# %%
df2
# Out:
#                             Name      Speciality  \
# 0                            NaN             NaN
# 1           Dr. Ramnaresh Soudri    Cardiologist
# 2        Dr. Prabhakar C Koregol    Cardiologist
# 3                   Dr. Roopa. R    Cardiologist
# 4                 Dr. Balaraju D    Cardiologist
# ...                          ...             ...
# 2150             Dr. Nitesh Jain  Rheumatologist
# 2151         Dr. Nimish Nanawati  Rheumatologist
# 2152              Dr. RPS Hasija  Rheumatologist
# 2153  Dr. Tushar Tanaji Telvekar  Rheumatologist
# 2154               Dr. Isha Sood  Rheumatologist
#
#                                                  Degree  \
# 0                                                   NaN
# 1          MBBS, MD - General Medicine, DM - Cardiology
# 2          DM - Cardiology, MD - General Medicine, MBBS
# 3         MBBS, MD - General Medicine, DNB - Cardiology
# 4         MD - General Medicine, DNB - Cardiology, MBBS
# ...                                                 ...
# 2150  MBBS, Diploma in Orthopaedics, MRCS (UK), DNB ...
# 2151                            MBBS, MD - Rheumatology
# 2152  Fellowship in Rheumatology, Graduate Certifica...
# 2153  MD - Physician, DNB - Rheumatology, Diploma in...
# 2154    MD - General Medicine, MBBS, DNB - Rheumatology
#
#                                      Year_of_experience  \
# 0                                                   NaN
# 1                            6 Years Experience Overall
# 2     24 Years Experience Overall  (15 years as spec...
# 3     24 Years Experience Overall  (11 years as spec...
# 4     13 Years Experience Overall  (6 years as speci...
# ...                                                 ...
# 2150  21 Years Experience Overall  (14 years as spec...
# 2151  41 Years Experience Overall  (40 years as spec...
# 2152                         8 Years Experience Overall
# 2153  9 Years Experience Overall  (3 years as specia...
# 2154  15 Years Experience Overall  (2 years as speci...
#
#                                Location       City dp_score           npv  \
# 0                                   NaN        NaN      NaN           NaN
# 1                 HSR Layout, Bangalore  Bangalore      97%    (30 votes)
# 2                Malleswaram, Bangalore  Bangalore      97%  (1589 votes)
# 3     Banashankari 2nd Stage, Bangalore  Bangalore      95%   (180 votes)
# 4          Jayanagar 9 Block, Bangalore  Bangalore      95%   (180 votes)
# ...                                 ...        ...      ...           ...
# 2150             Kandivali East, Mumbai     Mumbai      89%    (28 votes)
# 2151             Vileparle West, Mumbai     Mumbai      92%    (25 votes)
# 2152               Andheri East, Mumbai     Mumbai      92%    (25 votes)
# 2153                    Mazgaon, Mumbai     Mumbai      92%    (25 votes)
# 2154              Borivali West, Mumbai     Mumbai      92%    (25 votes)
#
#      consultation_fee
# 0                 NaN
# 1           ₹ 800 fee
# 2           ₹ 700 fee
# 3           ₹ 650 fee
# 4           ₹ 750 fee
# ...               ...
# 2150        ₹ 500 fee
# 2151       ₹ 3000 fee
# 2152       ₹ 1500 fee
# 2153        ₹ 400 fee
# 2154       ₹ 1200 fee
#
# [2155 rows x 9 columns]

# %%
df2['Speciality'].value_counts()
# Out:
# Gynecologist/obstetrician    917
# Dentist                      643
# Orthopedist                  320
# Cardiologist                 223
# Rheumatologist                47
# Name: Speciality, dtype: int64
